# %%
import numpy as np

num_dim = 1024
num_stacks = 8
num_data = num_dim * num_stacks
num_symbols = num_dim * num_stacks * 2

bits = np.random.randint(0, 4, num_symbols)
args = np.pi * 0.5 * (bits + 0.5)
x_bits = np.cos(args) + 1j * np.sin(args)

noise_power = 0.3 / np.sqrt(2)
noise = np.random.randn(num_symbols) + 1j * np.random.randn(num_symbols)
x_sigs = x_bits + noise_power * noise

x_data = np.vstack((x_sigs.real, x_sigs.imag))
x_data = np.transpose(x_data)
y_data = bits
y_data = y_data.reshape(-1,1)

x_train = x_data[:num_data]
y_train = y_data[:num_data]

x_test = x_data[num_data:]
y_test = y_data[num_data:]

print(x_data.shape, x_train.shape, x_test.shape)
print(y_data.shape, y_train.shape, y_test.shape)
# Out:
# (16384, 2) (8192, 2) (8192, 2)
# (16384, 1) (8192, 1) (8192, 1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.plot(x_sigs.real, x_sigs.imag, '.')
plt.axis([-2, 2, -2, 2])
plt.grid()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Flatten(input_shape=(x_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, validation_split=0.2)

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 205/205 [==============================] - 2s 4ms/step - loss: 0.6110 - accuracy: 0.9223 - val_loss: 0.1836 - val_accuracy: 0.9994
# Epoch 2/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9997 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 3/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9998 - val_loss: 0.0270 - val_accuracy: 1.0000
# Epoch 4/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 5/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9997 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 6/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9998 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 7/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.9998 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 8/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 9/10
# 205/205 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 10/10
# 205/205 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 0.9998 - val_loss: 0.0059 - val_accuracy: 0.9988
# 256/256 [==============================] - 1s 2ms/step - loss: 0.0051 - accuracy: 0.9994
# [0.005062018521130085, 0.9993896484375]

# %%
plt.figure(figsize=(12,6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], '.-', label='loss')
plt.plot(history.history['val_loss'], '.-', label='val_loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], '.-', label='accuracy')
plt.plot(history.history['val_accuracy'], '.-', label='val_accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.show()
